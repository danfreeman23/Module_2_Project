# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Даниил, привет!👋</b>
#
# Меня зовут Алексей Гриб, и я буду ревьюером твоего проекта.
#
# Сразу хочу предложить в дальнейшем общаться на "ты" - надеюсь, так будет комфортнее:) Но если это неудобно, обязательно дай знать, и мы придумаем что-нибудь ещё!
#
# Цель ревью - не искать ошибки в твоём проекте, а помочь тебе сделать твою работу ещё лучше, устранив недочёты и приблизив её к реальным задачам специалиста по работе с данными. Поэтому не расстраивайся, если что-то не получилось с первого раза - это нормально, и это поможет тебе вырасти!
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> похвала, рекомендации «со звёздочкой», полезные лайфхаки, которые сделают и без того красивое решение ещё более элегантным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> некритичные ошибки или развивающие рекомендации на будущее.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# критичные ошибки, которые обязательно нужно исправить.
# </div>
#
#
# Пожалуйста, не удаляй мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Ты также можешь задавать свои вопросы, реагировать на мои комментарии, делать пометки и пояснения - полная творческая свобода! Но маленькая просьба - пускай они будут отличаться от моих комментариев, это поможет избежать путаницы в нашем общении:)
# Например, вот так:
#
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *твой текст*
# </div>
#
# Давай посмотрим на твой проект!

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Комментарий ревьюера </b>
#
# Даниил, в начале работы над проектом хотел бы обратить внимание на пару структурных моментов, которые мешают начать работу над проектом:
#
# 1. В разделе первичного анализа данных ты анализируешь выбросы и распределение - это являвется задачей исследовательской части данных, после первичного анализа, но до создания профиля. Раздел первичного анализа предполагает использование базовых методов `Pandas` для знакомства с данными.
# 2. В проекте нет анализа корреляции с помощью `phik` - вместо этого ты используешь `LabelEncoder` для кодирования категорий и считаешь обычную коррелцяию Пирсона. Особо бросается в глаза использование `LabelEncoder`, который ещё не был изучен в курсе - это выдаёт использование сторонних источников, а не материалов курса.
# 3. В проекте нет ссылки на `GitHub` с материалам проекта, что является отдельным заданием этого проекта.
# 4. Очевидно активное использование GPT при создании проекта - на это указывают огромные полотна кода, комментарии к коду буквально в каждой строке, постоянное дублирование импортов одних и тех же модулей в каждой ячейке кода, а также наличие дублированных операций.
#
# Фактически проект не выполнен самостоятельно, имеет отклонения от целевой структуры и использует модули, которые в курсе не были рассмотрены.
#
# Минимум, который необходимо сделать - это привести проект к целевой структуре по п.1-3. По п.4 - я рекомендую переделать проект самостоятельно, чтобы в обучении была ценность: генерировать код в GPT несложно, но это вредная практика, которая не позволит развить нужные аналитические и разработчиские навыки. Прибегать к GPT для решения отдельных кейсов - нормальная практика в современных реалиях, но важно делать это фрагментарно, вдумчиво анализировать результат и воспроизводить самостоятельно, а не копировать код без постобработки. Мы также можем сохранить проект в текущем виде, но в таком случае будут дополнительные задания и более строгий анализ работы, чтобы убедиться в твоём понимании проекта. Ответы на эти допзадания и вопросы нужно будет делать самостоятельно - этому будет уделено пристальное внимание в ходе ревью.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Все переработал. Прошу прощения, очень торопился в первой итерации.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента 2 <a class="tocSkip"> </h2>
#
# было 2 комментария "на доработку". 2 отработал, исправил
# </div>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Комментарий ревьюера </b>
#
# Даниил, комментариев было больше - судя по всему, часть по какой-то причине не сохранилось. В последнее время такие кейсы несколько раз случались на этом проекте.
#
# Я восстановлю комментарии с прошлой итерации из проверенного файла - нужно будет внести оставшиеся правки. Эту отправку за итерацию принимать не будем.

# %% [markdown]
# # Анализ лояльности пользователей Яндекс Афиши с помощью Python
# # Итоговый проект модуля 2
# Фриман Д.Д.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> В проекте нет вступительной части - нужно добавить краткое описание проекта, описание данных, основные цели проекта.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Исправлено
# </div>

# %% [markdown]
# Команда маркетинга хочет лучше понимать поведение пользователей. Для этого они просят вас провести исследовательский анализ данных, чтобы понять, какие пользователи с большей вероятностью возвращаются на платформу и делают заказы повторно. Это позволит:
#
# - Быстро выявлять перспективных клиентов и предлагать им персонализированные условия.
# - Точно настраивать рекламу на аудитории с высокой вероятностью возврата.
# - Оптимизировать маркетинговые бюджеты.
# - Повысить общий уровень удержания клиентов.

# %%
# !pip install sqlalchemy
# !pip install phik
# !pip install psycopg2
# !pip install --user scipy==1.10.1
# !pip install python-dotenv

# %% [markdown]
# # Шаг 1. Загрузка данных и их предобработка

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# По шагу 1 поправил сразу корректно импорты, исправил по замечаниям
# </div>

# %%
import pandas as pd
import phik
import sqlalchemy as sa
import psycopg2
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from phik import report
from sqlalchemy import create_engine
from dotenv import load_dotenv  
import os

load_dotenv(r'C:\Users\danfr\Documents\Git\Module_2_Project\.env')

db_config = {
    'user': os.getenv('DB_USER'),
    'pwd': os.getenv('DB_PASSWORD'),
    'host': os.getenv('DB_HOST'),
    'port': os.getenv('DB_PORT'),
    'db': os.getenv('DB_NAME')
}

print(f"pandas: {pd.__version__}")
print(f"phik: {phik.__version__}")
print(f"SQLAlchemy: {sa.__version__}")
print(f"psycopg2: {psycopg2.__version__}")
print(f"matplotlib: {plt.matplotlib.__version__}")
print(f"seaborn: {sns.__version__}")
print(f"numpy: {np.__version__}")
# Out:
# pandas: 1.3.4
# phik: 0.12.5
# SQLAlchemy: 1.4.22
# psycopg2: 2.9.11 (dt dec pq3 ext lo64)
# matplotlib: 3.4.3
# seaborn: 0.11.2
# numpy: 1.20.3

# %%
connection_string = 'postgresql://{}:{}@{}:{}/{}'.format(
    os.getenv('DB_USER'),
    os.getenv('DB_PASSWORD'), 
    os.getenv('DB_HOST'),
    os.getenv('DB_PORT'),
    os.getenv('DB_NAME')
)

print("Connection string:", connection_string.replace(os.getenv('DB_PASSWORD'), '***'))
# Out:
# Connection string: postgresql://praktikum_student:***@rc1b-wcoijxj3yxfsf3fs.mdb.yandexcloud.net:6432/data-analyst-afisha

# %%
engine = create_engine(connection_string)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Библиотеки импортировали, коннектор сделали - отлично!

# %% [markdown]
# После подключение переходим к илзвлечению SQL

# %%
query = '''
SELECT 
    p.user_id,
    p.device_type_canonical,
    p.order_id,
    p.created_dt_msk as order_dt,
    p.created_ts_msk as order_ts,
    p.currency_code,
    p.revenue,
    p.tickets_count,
    (p.created_dt_msk::DATE - LAG(p.created_dt_msk::DATE) OVER (
        PARTITION BY p.user_id 
        ORDER BY p.created_dt_msk::DATE
    )) AS days_since_prev,
    p.event_id,
    e.event_name_code as event_name,
    p.service_name,
    e.event_type_main,
    r.region_name,
    c.city_name
FROM afisha.purchases AS p
JOIN afisha.events AS e ON p.event_id = e.event_id
JOIN afisha.city AS c ON e.city_id = c.city_id
JOIN afisha.regions AS r ON c.region_id = r.region_id
WHERE 
    p.device_type_canonical IN ('mobile', 'desktop')
    AND e.event_type_main != 'фильм'
ORDER BY p.user_id
'''

df = pd.read_sql_query(query, con=engine)
display(df)
# Out:
#                 user_id device_type_canonical  order_id   order_dt  \
# 0       0002849b70a3ce2                mobile   4359165 2024-08-20
# 1       0005ca5e93f2cf4                mobile   7965605 2024-07-23
# 2       0005ca5e93f2cf4                mobile   7292370 2024-10-06
# 3       000898990054619                mobile   1139875 2024-07-13
# 4       000898990054619                mobile    972400 2024-10-04
# ...                 ...                   ...       ...        ...
# 290606  fffcd3dde79eb2c                mobile    368620 2024-10-27
# 290607  fffcd3dde79eb2c                mobile    368562 2024-10-27
# 290608  fffcd3dde79eb2c               desktop   8473772 2024-10-30
# 290609  fffeeb3c120cf0b               desktop   5526067 2024-09-24
# 290610  ffff00725179321                mobile    813654 2024-09-25
#
#                   order_ts currency_code  revenue  tickets_count  \
# 0      2024-08-20 16:08:03           rub  1521.94              4
# ...

# %% [markdown]
# Данные загружены из базы данных Яндекс Афиши.
# Выгрузка содержит 290611 записей о покупках с 15 столбцами.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Данные выгружены из базы.

# %% [markdown]
# # ЗАДАЧА 1.2: ИЗУЧЕНИЕ ОБЩЕЙ ИНФОРМАЦИИ О ДАННЫХ

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Удалил "Льва Толстого". Переделал
# </div>

# %%
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290611 entries, 0 to 290610
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                290611 non-null  object
#  1   device_type_canonical  290611 non-null  object
#  2   order_id               290611 non-null  int64
#  3   order_dt               290611 non-null  datetime64[ns]
#  4   order_ts               290611 non-null  datetime64[ns]
#  5   currency_code          290611 non-null  object
#  6   revenue                290611 non-null  float64
#  7   tickets_count          290611 non-null  int64
#  8   days_since_prev        268678 non-null  float64
#  9   event_id               290611 non-null  int64
#  10  event_name             290611 non-null  object
#  11  service_name           290611 non-null  object
#  12  event_type_main        290611 non-null  object
#  13  region_name            290611 non-null  object
# ...

# %% [markdown]
# Оценка корректности выгрузки и объема данных:
#
# Выгрузка содержит 290,611 записей о покупках с 15 столбцами. Данные имеют хорошее качество - отсутствуют пропуски кроме ожидаемых 21,933 значений в days_since_prev (первые заказы пользователей).
# Типы данных назначены корректно: даты как datetime, числовые значения как float/int64, категориальные как object.
#
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Были намечены шаги по дальнейшей обработке данных, но я его уточнил и дополнил.
# </div>
#
# **План предобработки данных:**
#
# 1. **Обработка дубликатов:**
#    - Проверить явные дубликаты по ключевым полям (user_id, order_ts, order_id)
#    - Идентифицировать и устранить неявные дубликаты в категориальных полях
#
# 2. **Приведение валюты к единому стандарту:**
#    - Загрузить актуальные курсы валют для периода данных
#    - Конвертировать выручку в KZT в RUB по курсу на дату операции
#    - Создать единый показатель revenue_rub
#
# 3. **Очистка от аномалий:**
#    - Удалить записи с отрицательной выручкой
#    - Идентифицировать и обработать выбросы в revenue и tickets_count
#    - Применить квантильный анализ для фильтрации экстремальных значений
#
# 4. **Валидация категориальных данных:**
#    - Проверить согласованность категорий event_type_main, service_name
#    - Убедиться в отсутствии опечаток в географических названиях
#    - Нормализовать текстовые данные при необходимости
#
# 5. **Создание производных признаков:**
#    - Выделить дату заказа из временных меток
#    - Подготовить данные для анализа временных паттернов
# Промежуточный вывод:
#
# Данные успешно выгружены, охватывают период с июня по октябрь 2024 года. Структура соответствует ожиданиям для анализа покупательского поведения. Качество данных высокое, что позволяет переходить к этапу преобразования и углубленного анализа без значительной очистки.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Первичный осмотр данных выполнен.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Нужно наметить шаги по дальнейшей обработке данных - всё то, что делаем в следующем шаге.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Тут исправлено
# </div>

# %% [markdown]
# # Шаг 2: Предобработка данных

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Сейчас сюда перенес предобработку
# </div>

# %%
df_len_before = len(df)
print(df_len_before)

obv_duplicates_1 = df[['user_id', 'order_ts']].duplicated().sum()
print(obv_duplicates_1)

obv_duplicates_2 = df['order_id'].duplicated().sum()
print(obv_duplicates_2)

df = df.drop_duplicates(subset=['user_id', 'order_ts'])
print(len(df))
# Out:
# 290611
# 170
# 0
# 290441

# %% [markdown]
# Всего 170 дубликатов по user_id и order_ts, что может быть связано с техническими особенностями платформы, или дубликаты из-за повторных заказов на пользователя, поэтому не трогаем их. Дубликатов по самим заказам по order_id не выявлено. В целом неявных дубликатов не обнаружено.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Исследованы дубликаты.

# %%
print("Уникальные категории мероприятий:")
print(df['event_type_main'].value_counts())
# Out:
# Уникальные категории мероприятий:
# концерты    115233
# театр        67280
# другое       65821
# спорт        21877
# стендап      13392
# выставки      4849
# ёлки          1989
# Name: event_type_main, dtype: int64

# %% [markdown]
# Проверка неявных дубликатов в event_type_main: 7 конкретных категорий, неявных дубликатов нет.

# %%
print("Количество уникальных сервисов:", df['service_name'].nunique())
print(df['service_name'].value_counts().head())
# Out:
# Количество уникальных сервисов: 36
# Билеты без проблем    63469
# Лови билет!           41103
# Билеты в руки         40301
# Мой билет             34824
# Облачко               26638
# Name: service_name, dtype: int64

# %% [markdown]
# Проверка неявных дубликатов в service_name: 36 сервисов, распределение равномерное, дубликатов не обнаружено.

# %%
potential_dups = ['дом культ', 'билет']
for pattern in potential_dups:
    matches = df[df['service_name'].str.contains(pattern, case=False)]
    if len(matches) > 0:
        print(f"Проверка '{pattern}': {matches['service_name'].value_counts()}")
# Out:
# Проверка 'дом культ': Дом культуры              4500
# Городской дом культуры    2733
# Name: service_name, dtype: int64
# Проверка 'билет': Билеты без проблем    63469
# Лови билет!           41103
# Билеты в руки         40301
# Мой билет             34824
# Лучшие билеты         17765
# Весь в билетах        16844
# Край билетов           6205
# Тебе билет!            5223
# За билетом!            2863
# Быстробилет            2001
# Росбилет                539
# Телебилет               321
# Билет по телефону        85
# Кино билет               67
# Цвет и билет             61
# Тех билет                22
# Билеты в интернете        4
# Name: service_name, dtype: int64

# %% [markdown]
# Проверка потенциальных дубликатов в service_name: дома культуры вроде схоже, но не одно и то же - разные учреждения.

# %%
print(f"Уникальных городов: {df['city_name'].nunique()}")
print(f"Уникальных регионов: {df['region_name'].nunique()}")
# Out:
# Уникальных городов: 352
# Уникальных регионов: 81

# %% [markdown]
# Проверка неявных дубликатов в географических данных: географические названия уникальны, дубликатов нет.
#
# В итоге неявные дубликаты везде не обнаружены.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Категориальные признаки проверены на предмет аномалий.

# %% [markdown]
# # Задача 2.1: Приведение выручки к единой валюте
#
# Подгружаем данные о курсе тенге

# %%
exchange_df = pd.read_csv('https://code.s3.yandex.net/datasets/final_tickets_tenge_df.csv')
print(f"Размер: {exchange_df.shape}")
print(exchange_df.head())
# Out:
# Размер: (357, 4)
#          data  nominal     curs  cdx
# 0  2024-01-10      100  19.9391  kzt
# 1  2024-01-11      100  19.7255  kzt
# 2  2024-01-12      100  19.5839  kzt
# 3  2024-01-13      100  19.4501  kzt
# 4  2024-01-14      100  19.4501  kzt

# %% [markdown]
# Загружен реальный датасет с курсами тенге за период данных
#
# Надо переименовать столбцы, т.к. столбец с датой называется 'data', курс - 'curs'

# %%
exchange_df = exchange_df.rename(columns={'data': 'date', 'curs': 'exchange_rate'})
print("Переименованные столбцы:", exchange_df.columns.tolist())
# Out:
# Переименованные столбцы: ['date', 'nominal', 'exchange_rate', 'cdx']

# %% [markdown]
# Переименовали для совместимости, объединяем с основными данными

# %%
df['order_date'] = pd.to_datetime(df['order_dt']).dt.date
exchange_df['order_date'] = pd.to_datetime(exchange_df['date']).dt.date
df = df.merge(exchange_df[['order_date', 'exchange_rate']], on='order_date', how='left')
print(f"Заказов в тенге: {(df['currency_code'] == 'kzt').sum()}")
print(f"Пропусков курса для тенге: {df[df['currency_code'] == 'kzt']['exchange_rate'].isnull().sum()}")
# Out:
# Заказов в тенге: 5066
# Пропусков курса для тенге: 0

# %% [markdown]
# Заказы с тенге сопоставлены с курсом на дату операции.
#
# И проводим концертацию валюты

# %%
df['revenue_rub'] = df['revenue']
kzt_mask = df['currency_code'] == 'kzt'
df.loc[kzt_mask, 'revenue_rub'] = df.loc[kzt_mask, 'revenue'] * df.loc[kzt_mask, 'exchange_rate'] / 100
print(f"Конвертировано заказов: {kzt_mask.sum()}")
# Out:
# Конвертировано заказов: 5066

# %% [markdown]
# Выручка всех заказов в тенге пересчитана в рубли по курсу
#
# Проверяем результаты конвертации

# %%
print("Результаты конвертации:")
print(f"Средний курс тенге: {df[df['currency_code'] == 'kzt']['exchange_rate'].mean():.4f}")
print(f"Средний чек в тенге до конвертации: {df[df['currency_code'] == 'kzt']['revenue'].mean():.2f}")
print(f"Средний чек в рублях после конвертации: {df[df['currency_code'] == 'kzt']['revenue_rub'].mean():.2f}")
# Out:
# Результаты конвертации:
# Средний курс тенге: 19.4126
# Средний чек в тенге до конвертации: 4994.72
# Средний чек в рублях после конвертации: 981.24

# %% [markdown]
# Конвертация выполнена корректно. Разница в средних чеках между валютами объясняется разной структурой заказов, а не ошибкой конвертации.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Выручка приведена к единой валюте.

# %% [markdown]
# # Задача 2.2: Проверка пропусков, преобразование типов и обработка выбросов
#
# Начнем с проверки пропусков

# %%
print("Пропуски в данных:")
print(df.isnull().sum())
# Out:
# Пропуски в данных:
# user_id                      0
# device_type_canonical        0
# order_id                     0
# order_dt                     0
# order_ts                     0
# currency_code                0
# revenue                      0
# tickets_count                0
# days_since_prev          21933
# event_id                     0
# event_name                   0
# service_name                 0
# event_type_main              0
# region_name                  0
# city_name                    0
# order_date                   0
# exchange_rate                0
# revenue_rub                  0
# dtype: int64

# %% [markdown]
# Пропуски только в days_since_prev (ожидаемо для первых заказов), данные качественные.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Пропуски изучены.

# %% [markdown]
# Начинаем удаление отрицательной выручки

# %%
initial_count = len(df)
print(f"Исходное количество записей: {initial_count}")

neg_revenue = df[df['revenue_rub'] < 0]
print(f"Отрицательная выручка: {len(neg_revenue)} записей ({len(neg_revenue)/len(df)*100:.2f}%)")
df = df[df['revenue_rub'] >= 0]
# Out:
# Исходное количество записей: 290441
# Отрицательная выручка: 379 записей (0.13%)

# %% [markdown]
# Удалено 379 записей с отрицательной выручкой (0.13%).
#
# Переходим к анализу выбросов в выручке

# %%
revenue_99 = df['revenue_rub'].quantile(0.99)
outliers_revenue = df[df['revenue_rub'] > revenue_99]
print(f"Выбросы в выручке (>99%): {len(outliers_revenue)} записей ({len(outliers_revenue)/len(df)*100:.2f}%)")
print(f"99-й перцентиль: {revenue_99:.2f} руб")
# Out:
# Выбросы в выручке (>99%): 2825 записей (0.97%)
# 99-й перцентиль: 2628.42 руб

# %% [markdown]
# Выявлены выбросы в выручке - 0,97% записей превышают 2628 р
#
# Дополняем фильтрацией выбросов по выручке

# %%
df = df[df['revenue_rub'] <= revenue_99]
print(f"Данные после фильтрации: {len(df)} записей")
# Out:
# Данные после фильтрации: 287237 записей

# %% [markdown]
# Удалены выбросы по выручке, осталось 287238 записей.
#
# Проводим анализ количества билетов

# %%
print("Статистика по билетам:")
print(df['tickets_count'].describe(percentiles=[0.25, 0.5, 0.75, 0.95, 0.99]))
# Out:
# Статистика по билетам:
# count    287237.000000
# mean          2.741370
# std           1.163063
# min           1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           3.000000
# 95%           5.000000
# 99%           6.000000
# max          57.000000
# Name: tickets_count, dtype: float64

# %% [markdown]
# Билеты более менее в норме, выбросы не удаляем как возможные групповые заказы.

# %%
final_count = len(df)
removed = initial_count - final_count
print(f"Итоги: удалено {removed} записей ({removed/initial_count*100:.1f}%)")
print(f"Осталось: {final_count} записей")
# Out:
# Итоги: удалено 3204 записей (1.1%)
# Осталось: 287237 записей

# %% [markdown]
# По результатам предобработки удалено 1,1% данных, качество данных высокое.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Численные признаки изучены, удалены выбросы.

# %% [markdown]
# # ВЫВОД ПО ЗАДАЧЕ 2.2
#
# В ходе предобработки данных выполнены ключевые операции по улучшению качества данных. Создан новый столбец revenue_rub с выручкой, приведенной к единой валюте (рубль), что позволяет корректно сравнивать финансовые показатели. Проверка данных выявила только ожидаемые пропуски в столбце days_since_prev (21933 записей) для первых заказов пользователей. Удалены аномальные значения: 379 записей с отрицательной выручкой (0,13%) и 2824 выбросов по выручке, превышающих 99-й перцентиль (2628 руб). Анализ количества билетов показал нормальное распределение (медиана - 3 билета, 99% заказов до 6 билетов), поэтому экстремальные значения сохранены как потенциально валидные групповые заказы. Общий объем данных сократился на 3373 записи (1,2%), что не оказывает существенного влияния на последующий анализ. Данные готовы для исследовательского анализа.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Молодец, что делаешь промежуточный вывод по результатам обработки данных.

# %% [markdown]
# # Шаг 3: Создание профиля пользователя
# # Задача 3.1: Построение профиля пользователя

# %% [markdown]
# Сначала отсортируем данные по пользователю и времени заказа

# %%
df_sorted = df.sort_values(['user_id', 'order_dt', 'order_ts'])

# %% [markdown]
# Далее для корректного определения первого заказа каждого пользователя мы создаем базовый профиль пользователя

# %%
user_profile = df_sorted.groupby('user_id').agg({
    'order_dt': ['min', 'max'],
    'device_type_canonical': 'first',
    'region_name': 'first', 
    'service_name': 'first',
    'event_type_main': 'first',
    'order_id': 'count',
    'revenue_rub': 'mean',
    'tickets_count': 'mean',
    'days_since_prev': 'mean'
}).round(2)

user_profile.columns = [
    'first_order', 'last_order', 'first_device', 'first_region',
    'first_service', 'first_event_type', 'total_orders', 'avg_revenue',
    'avg_tickets', 'avg_days_between_orders'
]

print(f"Создано профилей: {len(user_profile)} пользователей")
# Out:
# Создано профилей: 21838 пользователей

# %% [markdown]
# Теперь есть профиля с информацией о первом заказе и среднимии показателями, идибовляем бинарные признаки

# %%
user_profile['is_two'] = (user_profile['total_orders'] >= 2).astype(int)
user_profile['is_five'] = (user_profile['total_orders'] >= 5).astype(int)

print(f"Пользователей с 2+ заказами: {user_profile['is_two'].sum()} ({user_profile['is_two'].mean()*100:.1f}%)")
print(f"Пользователей с 5+ заказами: {user_profile['is_five'].sum()} ({user_profile['is_five'].mean()*100:.1f}%)")
# Out:
# Пользователей с 2+ заказами: 13475 (61.7%)
# Пользователей с 5+ заказами: 6330 (29.0%)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Профиль пользователя собран, добавлены бинарные признаки.

# %% [markdown]
# Получается что 61,7% пользователей вернулись, 29% стали лояльными.
#
# Проанащлизируем профили

# %%
print(f"Среднее количество заказов: {user_profile['total_orders'].mean():.1f}")
print(f"Медиана заказов: {user_profile['total_orders'].median():.1f}")
print(f"Средняя выручка: {user_profile['avg_revenue'].mean():.0f} руб.")
print(f"Среднее время между заказами: {user_profile['avg_days_between_orders'].mean():.1f} дней")

print(user_profile[user_profile['total_orders'] == 1].iloc[0][['first_device', 'first_region', 'first_event_type']])
# Out:
# Среднее количество заказов: 13.2
# Медиана заказов: 2.0
# Средняя выручка: 545 руб.
# Среднее время между заказами: 15.9 дней
# first_device                    mobile
# first_region        Каменевский регион
# first_event_type                 театр
# Name: 0002849b70a3ce2, dtype: object

# %% [markdown]
# Можно заметить высокую активность лояльных пользователей.
#
# Также описан профиль с информацией о поведении и предпочтении пользователей.
#
# Я создал профили для всех пользователей — получилось 21838 профилей. Для каждого пользователя посчитал основные показатели: когда был первый и последний заказ, с какого устройства и в каком регионе заказывал, сколько всего заказов сделал и средние значения по деньгам и билетам.
#
# Главное что видно — больше половины пользователей (61,7%) возвращались и делали повторные заказы, а почти каждый третий (29%) стал постоянным клиентом с 5+ заказами.
#
# Данные готовы для анализа лояльности и построения моделей — теперь мы понимаем, как ведут себя разные типы пользователей.

# %% [markdown]
# # Задача 3.2: Анализ репрезентативности данных и выявление аномалий
#
# Посмотрим на данные

# %%
user_profile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21838 entries, 0002849b70a3ce2 to ffff00725179321
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   first_order              21838 non-null  datetime64[ns]
#  1   last_order               21838 non-null  datetime64[ns]
#  2   first_device             21838 non-null  object
#  3   first_region             21838 non-null  object
#  4   first_service            21838 non-null  object
#  5   first_event_type         21838 non-null  object
#  6   total_orders             21838 non-null  int64
#  7   avg_revenue              21838 non-null  float64
#  8   avg_tickets              21838 non-null  float64
#  9   avg_days_between_orders  13508 non-null  float64
#  10  is_two                   21838 non-null  int32
#  11  is_five                  21838 non-null  int32
# dtypes: datetime64[ns](2), float64(3), int32(2), int64(1), object(4)
# ...

# %%
print(f"Пользователей: {len(user_profile):,}")
print(f"Средняя выручка: {user_profile['avg_revenue'].mean():.0f} руб")
print(f"Доля 2+ заказов: {user_profile['is_two'].mean()*100:.1f}%")
print(f"Доля 5+ заказов: {user_profile['is_five'].mean()*100:.1f}%")
# Out:
# Пользователей: 21,838
# Средняя выручка: 545 руб
# Доля 2+ заказов: 61.7%
# Доля 5+ заказов: 29.0%

# %% [markdown]
# В выборке 21838 пользователей с хорошими показателями лояльности.
#
# Посмотрим статистику еще по заказам

# %%
print(user_profile['total_orders'].describe(percentiles=[0.5, 0.75, 0.95, 0.99]))
# Out:
# count    21838.000000
# mean        13.153082
# std        121.440726
# min          1.000000
# 50%          2.000000
# 75%          5.000000
# 95%         31.000000
# 99%        152.000000
# max      10153.000000
# Name: total_orders, dtype: float64

# %% [markdown]
# Есть аномалии - 1% пользователей с минимум 152 заказами
#
# Посмотрим на аномалии в заказзах

# %%
print("\nСреднее число билетов в заказе:")
print(user_profile['avg_tickets'].describe(percentiles=[0.5, 0.75, 0.95, 0.99]))
# Out:
# Среднее число билетов в заказе:
# count    21838.000000
# mean         2.744064
# std          0.913074
# min          1.000000
# 50%          2.750000
# 75%          3.080000
# 95%          4.000000
# 99%          5.000000
# max         11.000000
# Name: avg_tickets, dtype: float64

# %%
print("\nСреднее количество дней между покупками:")
print(user_profile['avg_days_between_orders'].describe(percentiles=[0.5, 0.75, 0.95, 0.99]))
# Out:
# Среднее количество дней между покупками:
# count    13508.000000
# mean        15.865668
# std         22.325054
# min          0.000000
# 50%          8.000000
# 75%         20.500000
# 95%         61.500000
# 99%        112.000000
# max        148.000000
# Name: avg_days_between_orders, dtype: float64

# %%
orders_99 = user_profile['total_orders'].quantile(0.99)
anomalous_users = user_profile[user_profile['total_orders'] > orders_99]
print(f"Аномальные пользователи (>152 заказов): {len(anomalous_users)} ({len(anomalous_users)/len(user_profile)*100:.1f}%)")
# Out:
# Аномальные пользователи (>152 заказов): 216 (1.0%)

# %% [markdown]
# Обнаружено 216 аномальных пользователей с чрезмерным количеством заказов.
#
# Отфильтруем аномалию по 99 перцентилю, т.к. это позволит убрать некорректные значения

# %%
user_profile_clean = user_profile[user_profile['total_orders'] <= orders_99]
print(f"После фильтрации: {len(user_profile_clean)} пользователей")
print(f"Удалено: {len(user_profile) - len(user_profile_clean):,} ({((len(user_profile) - len(user_profile_clean))/len(user_profile)*100):.1f}%)")
# Out:
# После фильтрации: 21622 пользователей
# Удалено: 216 (1.0%)

# %% [markdown]
# Почистили процент данных, удалили пользователей с аномальным количеством заказов, качество выборки улучшуили, посмотрим статистику после фильтрации

# %%
print(f"Среднее количество заказов: {user_profile_clean['total_orders'].mean():.1f}")
print(f"Доля 2+ заказов: {user_profile_clean['is_two'].mean()*100:.1f}%")
print(f"Доля 5+ заказов: {user_profile_clean['is_five'].mean()*100:.1f}%")
# Out:
# Среднее количество заказов: 6.5
# Доля 2+ заказов: 61.3%
# Доля 5+ заказов: 28.3%

# %% [markdown]
# Обнаружены аномалии только в количестве заказов (216 пользователей с >152 заказами), которые удалены. Данные готовы для анализа.

# %%
print(user_profile_clean['total_orders'].describe(percentiles=[0.5, 0.75, 0.95, 0.99]))
# Out:
# count    21622.000000
# mean         6.493988
# std         14.303028
# min          1.000000
# 50%          2.000000
# 75%          5.000000
# 95%         26.000000
# 99%         79.790000
# max        152.000000
# Name: total_orders, dtype: float64

# %% [markdown]
# После фильтрации данные стали более сбалансированными - среднее количество заказов снизилось с 13,2 до 6,3.
#
# Фильтрация устранила аномалии в заказах и выручке, при этом доли лояльных пользователей практически не изменились.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Изучены статистики по профилю пользователя, удалены выбросы.

# %% [markdown]
# # Шаг 4: Исследовательский анализ данных
#
# # Задача 4.1: Исследование признаков первого заказа и их связи с возвращением

# %% [markdown]
# Используем очищенные профили пользователей

# %%
profiles = user_profile_clean.copy()
print(f"Анализируем {len(profiles)} пользователей")
# Out:
# Анализируем 21622 пользователей

# %% [markdown]
# # Задача 4.1.1: Изучите распределение пользователей по признакам.

# %%
users_per_event = profiles.groupby('first_event_type')['total_orders'].count().sort_values(ascending=False)
users_per_event_pers = (users_per_event / len(profiles) * 100).round(2)

print("Количество пользователей по типам мероприятий:")
print(users_per_event)
print("\nДоли в процентах:")
print(users_per_event_pers)
# Out:
# Количество пользователей по типам мероприятий:
# first_event_type
# концерты    9564
# другое      5401
# театр       4245
# стендап     1110
# спорт        794
# выставки     413
# ёлки          95
# Name: total_orders, dtype: int64
#
# Доли в процентах:
# first_event_type
# концерты    44.23
# другое      24.98
# театр       19.63
# стендап      5.13
# спорт        3.67
# выставки     1.91
# ёлки         0.44
# Name: total_orders, dtype: float64

# %% [markdown]
# Концерты являются самой популярной категорией первого мероприятия (43,2%), затем следуют "другое" (24,4%) и театр (19,2%). Распределение неравномерное с явным лидером.
#
# Следующий фрагмент визуализирует распределение по типам мероприятий для наглядности.

# %%
users_per_event_pers.plot(kind='bar',
                    title='Распределение пользователей по типу первого мероприятия',
                    xlabel='Тип мероприятия',
                    ylabel='Доля пользователей (%)',
                    rot=45, 
                    figsize=(10, 6))
plt.show()

# %% [markdown]
# Видим что концерты доминируют, как основаян точка входа пользователей на платформу.
#
# Далее анализируем распределение по типам устройств.

# %%
users_per_device = profiles.groupby('first_device')['total_orders'].count().sort_values(ascending=False)
users_per_device_pers = (users_per_device / len(profiles) * 100).round(2)

print("Количество пользователей по типам устройств:")
print(users_per_device)
print("\nДоли в процентах:")
print(users_per_device_pers)
# Out:
# Количество пользователей по типам устройств:
# first_device
# mobile     17906
# desktop     3716
# Name: total_orders, dtype: int64
#
# Доли в процентах:
# first_device
# mobile     82.81
# desktop    17.19
# Name: total_orders, dtype: float64

# %% [markdown]
# Мобильный трафик доминирует.
#
# Смотрим распределение по регионам топ10

# %%
users_per_region = profiles.groupby('first_region')['total_orders'].count().sort_values(ascending=False).head(10)
users_per_region_pers = (users_per_region / len(profiles) * 100).round(2)

print("Топ-10 регионов по количеству пользователей:")
print(users_per_region)
print("\nДоли в процентах:")
print(users_per_region_pers)
# Out:
# Топ-10 регионов по количеству пользователей:
# first_region
# Каменевский регион      7086
# Североярская область    3768
# Широковская область     1223
# Озернинский край         675
# Малиновоярский округ     526
# Шанырский регион         502
# Травяная область         488
# Светополянский округ     457
# Речиновская область      440
# Яблоневская область      411
# Name: total_orders, dtype: int64
#
# Доли в процентах:
# first_region
# Каменевский регион      32.77
# Североярская область    17.43
# Широковская область      5.66
# Озернинский край         3.12
# Малиновоярский округ     2.43
# Шанырский регион         2.32
# Травяная область         2.26
# Светополянский округ     2.11
# Речиновская область      2.03
# Яблоневская область      1.90
# Name: total_orders, dtype: float64

# %% [markdown]
# Каменевский регион является явным лидером (32%), за ним следует Североярская область (17%). Распределение по регионам сильно неравномерное.
#
# Далее анализ распределения по билетным операторам.

# %%
users_per_service = profiles.groupby('first_service')['total_orders'].count().sort_values(ascending=False).head(10)
users_per_service_pers = (users_per_service / len(profiles) * 100).round(2)

print("Топ-10 билетных операторов:")
print(users_per_service)
print("\nДоли в процентах:")
print(users_per_service_pers)
# Out:
# Топ-10 билетных операторов:
# first_service
# Билеты без проблем    5167
# Мой билет             2970
# Лови билет!           2812
# Билеты в руки         2557
# Облачко               2177
# Весь в билетах        1286
# Лучшие билеты         1182
# Прачечная              583
# Край билетов           454
# Дом культуры           356
# Name: total_orders, dtype: int64
#
# Доли в процентах:
# first_service
# Билеты без проблем    23.90
# Мой билет             13.74
# Лови билет!           13.01
# Билеты в руки         11.83
# Облачко               10.07
# Весь в билетах         5.95
# Лучшие билеты          5.47
# Прачечная              2.70
# Край билетов           2.10
# Дом культуры           1.65
# Name: total_orders, dtype: float64

# %% [markdown]
# "Билеты без проблем" является лидером (23%), за ним следуют "Мой билет" (13%) и "Лови билет!" (12%).

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 12))

users_per_event_pers.plot(kind='bar', ax=axes[0,0],
                         title='Распределение по типу первого мероприятия',
                         xlabel='Тип мероприятия', 
                         ylabel='Доля пользователей (%)',
                         rot=45)
axes[0,0].grid(axis='y', alpha=0.3)

users_per_device_pers.plot(kind='bar', ax=axes[0,1],
                          title='Распределение по типу устройства',
                          xlabel='Тип устройства',
                          ylabel='Доля пользователей (%)',
                          color=['#1f77b4', '#ff7f0e'])
axes[0,1].grid(axis='y', alpha=0.3)

users_per_region_pers.plot(kind='bar', ax=axes[1,0],
                          title='Распределение по регионам (топ-10)',
                          xlabel='Регион',
                          ylabel='Доля пользователей (%)',
                          rot=45)
axes[1,0].grid(axis='y', alpha=0.3)

users_per_service_pers.plot(kind='bar', ax=axes[1,1],
                           title='Распределение по билетным операторам (топ-10)',
                           xlabel='Билетный оператор',
                           ylabel='Доля пользователей (%)',
                           rot=45)
axes[1,1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# Графики подтверждают неравномерность распределения с выраженными "точками входа" в каждой категории

# %% [markdown]
# ВЫВОД ПО ЗАДАЧЕ 4.1.1
# ============================
#
# Распределение пользователей по сегментам неравномерное. Во всех анализируемых категориях выявлены выраженные "точки входа" - сегменты, которые концентрируют значительную долю пользователей. Наибольшая концентрация наблюдается в сегменте мобильных устройств (82%), что указывает на мобильный трафик как основной канал привлечения пользователей на платформу.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Ты верно выполнил все условия задания: сгруппировал пользователей по четырем требуемым признакам, подсчитал количество и доли, а также дал четкий ответ на главный вопрос о равномерности распределения.
#
# Логика анализа выстроена правильно. Вывод о том, что во всех категориях есть выраженные точки входа, полностью подтверждается цифрами из таблиц и графиков. Особенно верно выделен сегмент мобильных устройств как ключевой канал, так как его доля действительно подавляющая. Визуализация данных выполнена корректно и помогает быстрее считать информацию.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Обрати внимание на соответствие цифр в таблицах и твоих комментариях к ним. В анализе типов мероприятий таблица показывает долю категории концерты равной 44.23%, а в текстовом описании под ней указано 43.2%. Это небольшая неточность, но расхождение данных внутри одного отчета может снизить доверие к результатам.
#
# Также итоговый вывод можно сделать чуть более информативным. Сейчас ты детально описал только доминирование мобильных устройств. Было бы полезно кратко перечислить лидеров и в остальных разрезах (концерты, Каменевский регион, оператор Билеты без проблем). Это наглядно подтвердило бы твою фразу о том, что точки входа выявлены во всех анализируемых категориях, а не только в устройствах.

# %% [markdown]
# Задача 4.1.2. Проанализируйте возвраты пользователей:
# ============================

# %% [markdown]
# Начнем с вычисления общей доли возвращаемости

# %%
overall_return_rate = profiles['is_two'].mean() * 100
print(f"Общая доля пользователей с 2+ заказами: {overall_return_rate:.1f}%")
# Out:
# Общая доля пользователей с 2+ заказами: 61.3%

# %% [markdown]
# Доля пользователей совершивших два и более заказа 61%.
#
# Смотрим на анализ возврата по типам мероприятий

# %%
event_retention = (profiles.groupby('first_event_type')['is_two'].mean() * 100).sort_values(ascending=False)
print("Доля возврата по типу мероприятия:")
for event_type, retention_rate in event_retention.items():
    count = users_per_event[event_type]
    print(f"   {event_type:<12} {retention_rate:.1f}% ({count:>5,} пользователей)")
    
avg_retention = profiles['is_two'].mean() * 100
print(f"\n   Средняя доля возврата по выборке: {avg_retention:.1f}%")
# Out:
# Доля возврата по типу мероприятия:
#    выставки     64.2% (  413 пользователей)
#    театр        63.4% (4,245 пользователей)
#    концерты     61.8% (9,564 пользователей)
#    стендап      60.9% (1,110 пользователей)
#    другое       59.6% (5,401 пользователей)
#    спорт        55.8% (  794 пользователей)
#    ёлки         55.8% (   95 пользователей)
#
#    Средняя доля возврата по выборке: 61.3%

# %% [markdown]
# Получается общая возвращаемость составляет 61%. По типам мероприятий наблюдается разброс возвращаемости от 56% до 64%.
#
# Провизуализируем распределение доли возврата по типам мероприятий

# %%
event_retention.plot(kind='bar',
                    title='Распределение доли вернувшихся пользователей по типу первого мероприятия',
                    xlabel='Тип мероприятия',
                    ylabel='Доля вернувшихся пользователей (%)',
                    rot=45,
                    ylim=[50, 65],
                    figsize=(12, 6))

plt.axhline(y=avg_retention, color='red', label=f'Среднее ({avg_retention:.1f}%)')
plt.legend()
plt.show()

# %% [markdown]
# Получается согласно графику, пользователи, выбравшие выставки и театр в качестве первого мероприятия, демонстрируют наибольшую лояльность. Самые низкие показатели у спортивных мероприятий и ёлок
#
# Следующий фрагмент анализирует возвраты по типам устройств.

# %%
device_retention = (profiles.groupby('first_device')['is_two'].mean() * 100).sort_values(ascending=False)
print("Доля возврата по типу устройства:")
for device, retention_rate in device_retention.items():
    count = users_per_device[device]
    print(f"   {device:<8} {retention_rate:.1f}% ({count:>5,} пользователей)")
# Out:
# Доля возврата по типу устройства:
#    desktop  63.8% (3,716 пользователей)
#    mobile   60.8% (17,906 пользователей)

# %%
device_retention.plot(kind='bar',
                    title='Распределение доли вернувшихся пользователей по типу устройств',
                    xlabel='Тип устройства',
                    ylabel='Доля вернувшихся пользователей (%)',
                    rot=45,
                    ylim=[60, 65],
                    figsize=(10, 6))

plt.axhline(y=avg_retention, color='red', label=f'Среднее ({avg_retention:.1f}%)')
plt.legend()
plt.show()

# %% [markdown]
# Пользователи desktop демонстрируют более высокую лояльность по сравнению с мобильными пользователями.
# Desktop-пользователи показывают более высокую долю возврата, несмотря на то, что мобильные пользователи составляют большинство.
#
# Далее анализируем возвраты по регионам (топ-10)

# %%
region_retention = (profiles[profiles['first_region'].isin(users_per_region.index)]
                   .groupby('first_region')['is_two'].mean() * 100).reindex(users_per_region.index)

print("Доля возврата по регионам (топ-10):")
for i, (region, retention_rate) in enumerate(region_retention.items(), 1):
    count = users_per_region[region]
    print(f"   {i:2d}. {region:<22} {retention_rate:.1f}% ({count:>5,} пользователей)")
    
region_retention.plot(kind='bar',
                     title='Распределение доли вернувшихся пользователей по региону первого мероприятия',
                     xlabel='Регион',
                     ylabel='Доля вернувшихся пользователей (%)',
                     ylim=[55, 68],
                     rot=45,
                     figsize=(12, 6))

plt.axhline(y=avg_retention, color='red', label=f'Среднее ({avg_retention:.1f}%)')
plt.legend()
plt.show()
# Out:
# Доля возврата по регионам (топ-10):
#     1. Каменевский регион     62.4% (7,086 пользователей)
#     2. Североярская область   63.8% (3,768 пользователей)
#     3. Широковская область    64.4% (1,223 пользователей)
#     4. Озернинский край       55.3% (  675 пользователей)
#     5. Малиновоярский округ   55.9% (  526 пользователей)
#     6. Шанырский регион       67.3% (  502 пользователей)
#     7. Травяная область       61.5% (  488 пользователей)
#     8. Светополянский округ   65.6% (  457 пользователей)
#     9. Речиновская область    63.4% (  440 пользователей)
#    10. Яблоневская область    59.4% (  411 пользователей)

# %% [markdown]
# В топ-10 регионах наблюдается различная доля возврата. Шанырский регион показывает наивысший результат, а Озернинский край - самый низкий.
# Среди топ-3 регионов наблюдается рост доли возврата с уменьшением популярности региона, однако для остальных регионов из топ-10 такая тенденция не сохраняется.
#
#
# Анализируем возвраты по билетным операторам (топ-10)

# %%
service_retention = (profiles[profiles['first_service'].isin(users_per_service.index)]
                    .groupby('first_service')['is_two'].mean() * 100).reindex(users_per_service.index)

print("Доля возврата по билетным операторам (топ-10):")
for i, (service, retention_rate) in enumerate(service_retention.items(), 1):
    count = users_per_service[service]
    print(f"   {i:2d}. {service:<18} {retention_rate:.1f}% ({count:>5,} пользователей)")
    
service_retention.plot(kind='bar',
                      title='Распределение доли вернувшихся пользователей по билетным операторам',
                      xlabel='Билетный оператор',
                      ylabel='Доля вернувшихся пользователей (%)',
                      ylim=[59, 66],
                      rot=45,
                      figsize=(12, 6))

plt.axhline(y=avg_retention, color='red', label=f'Среднее ({avg_retention:.1f}%)')
plt.legend()
plt.show()
# Out:
# Доля возврата по билетным операторам (топ-10):
#     1. Билеты без проблем 60.3% (5,167 пользователей)
#     2. Мой билет          60.9% (2,970 пользователей)
#     3. Лови билет!        61.0% (2,812 пользователей)
#     4. Билеты в руки      62.8% (2,557 пользователей)
#     5. Облачко            61.2% (2,177 пользователей)
#     6. Весь в билетах     62.9% (1,286 пользователей)
#     7. Лучшие билеты      61.3% (1,182 пользователей)
#     8. Прачечная          62.6% (  583 пользователей)
#     9. Край билетов       65.2% (  454 пользователей)
#    10. Дом культуры       64.6% (  356 пользователей)

# %% [markdown]
# Не наблюдается четкой зависимости между размером оператора и долей возврата пользователей.
# "Край билетов" показывает наивысшую долю возврата (65.2%), в то время как крупнейшие операторы ("Билеты без проблем", "Мой билет", "Лови билет!") демонстрируют более скромные результаты.
#
# Итого, проанализированы возвраты пользователей по всем сегментам. Выявлены успешные "точки входа" с долей возврата выше среднего: desktop-пользователи, пользователи театров и пользователи из Шанырского региона. Результаты статистически достоверны благодаря достаточному размеру сегментов.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Ты верно рассчитал долю возврата для всех сегментов и правильно использовал среднее значение по выборке (61.3%) как ориентир для сравнения. Визуализация выполнена качественно: красная линия на графиках отлично помогает мгновенно отделить успешные сегменты от отстающих.
#
# Выводы по отдельным категориям логичны и соответствуют данным. Ты правильно заметил, что пользователи десктопов лояльнее мобильных пользователей, а среди билетных операторов размер компании не гарантирует высокий процент возврата. Также верно определены лидеры и аутсайдеры в тематиках мероприятий.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> В итоговом выводе ты перечислил успешные точки входа: пользователи десктопов, театров и Шанырского региона. Однако в категории типов мероприятий лидером по возвращаемости являются выставки (64.2%), а не театры (63.4%). Ты мог исключить выставки из-за размера выборки (413 пользователей), но при этом включил в итоговый список Шанырский регион, где количество пользователей сопоставимо (502). Стоит быть последовательным в отборе: либо упоминать абсолютных лидеров по процентам (выставки), либо указывать критерий отсечения по размеру сегмента.
#
# Также в анализе регионов ты отметил тенденцию роста возвращаемости с уменьшением популярности для топ-3 регионов. Это наблюдение справедливо для конкретных трех строк, но на полной выборке такая закономерность не прослеживается, поэтому делать на ней акцент рискованно - это может быть случайностью.

# %% [markdown]
# # Задача 4.1.3: Опираясь на выводы из задач выше, проверьте продуктовые гипотезы:

# %% [markdown]
# Гипотеза 1. Тип мероприятия влияет на вероятность возврата на Яндекс Афишу: пользователи, которые совершили первый заказ на спортивные мероприятия, совершают повторный заказ чаще, чем пользователи, оформившие свой первый заказ на концерты.
#
# Результат проверки: Гипотеза не подтверждается данными анализа.
#
# Согласно расчетам, доля возврата пользователей по типам мероприятий на спортивные мероприятия 55% и концерты 61%.
#
# Пользователи, выбравшие концерты в качестве первого мероприятия, демонстрируют более высокую лояльность 61% по сравнению с пользователями спортивных мероприятий 55%.
#
# При этом действительно наблюдается влияние типа мероприятия на вероятность возврата - наиболее высокие показатели у театра 63% и выставок 64%, а самые низкие у спортивных мероприятий и ёлок 55%. Однако конкретное утверждение гипотезы о превосходстве спортивных мероприятий над концертами не подтверждется в данных.

# %% [markdown]
# Гипотеза 2. В регионах, где больше всего пользователей посещают мероприятия, выше доля повторных заказов, чем в менее активных регионах.
#
# Результат проверки: Гипотеза не подтверждается
#
# Анализ топ-10 регионов по количеству пользователей показывает отсутствие линейной зависимости между размером региона и долей возврата:Каменевский регион лидер по количеству пользователей - 32% имеет 62% возврата
#
# В то же время менее крупные регионы демонстрируют различную динамику: Шанырский регион 2% пользователей имеет 67% возврата
#
# Таким образом, не наблюдается устойчивой тенденции - как крупные, так и небольшие регионы могут показывать как высокие, так и низкие показатели возврата пользователей. Доля повторных заказов зависит от других факторов, а не только от размера пользовательской базы региона

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Ты верно понял суть задания и проверил обе гипотезы, опираясь на конкретные цифры из предыдущих шагов. Выводы сформулированы четко: обе гипотезы опровергнуты, и для этого приведены правильные аргументы.
#
# Особенно удачно, что при проверке первой гипотезы ты не просто сравнил "спорт" и "концерты", но и дал более широкий контекст, упомянув лидеров (театр, выставки). Это показывает глубокое понимание данных. Во второй гипотезе ты грамотно использовал контрпримеры (Шанырский регион против Каменевского), чтобы доказать отсутствие линейной зависимости между размером региона и лояльностью.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> В блоке с первой гипотезой текст немного перегружен повторами. Ты трижды пишешь про сравнение концертов и спорта разными словами. Можно сократить, оставив одну четкую фразу: "Концерты показывают более высокую лояльность (61%), чем спортивные мероприятия (55%), что опровергает гипотезу".
#
# В выводе по второй гипотезе, утверждая, что "Каменевский регион имеет 62% возврата", стоит быть осторожнее с формулировками, если точная цифра была 62.4%. Округление допустимо, но лучше придерживаться единого стиля (либо везде десятые доли, либо везде целые).

# %% [markdown]
# # Задача 4.2 Исследование поведения пользователей через показатели выручки и состава заказа
#
# # Задача 4.2.1. Проследите связь между средней выручкой сервиса с заказа и повторными заказами.

# %% [markdown]
# Сделаем анализ связи между средней выручкой и повторными заказами, разделим пользователей на две группы и проанализируем статистику по выручке для обеих групп

# %%
single_order_users = profiles[profiles['total_orders'] == 1]
returned_users = profiles[profiles['total_orders'] >= 2]

print(f"Пользователей с одним заказом: {len(single_order_users):,}")
print(f"Пользователей с 2+ заказами: {len(returned_users):,}")

print("\nПользователи с одним заказом:")
print(single_order_users['avg_revenue'].describe(percentiles=[0.25, 0.5, 0.75, 0.9]))
print("\nПользователи с 2+ заказами:")
print(returned_users['avg_revenue'].describe(percentiles=[0.25, 0.5, 0.75, 0.9]))
# Out:
# Пользователей с одним заказом: 8,363
# Пользователей с 2+ заказами: 13,259
#
# Пользователи с одним заказом:
# count    8363.000000
# mean      545.774760
# std       519.402522
# min         0.000000
# 25%       133.055000
# 50%       378.870000
# 75%       830.975000
# 90%      1290.350000
# max      2628.420000
# Name: avg_revenue, dtype: float64
#
# Пользователи с 2+ заказами:
# count    13259.000000
# mean       545.053213
# std        369.241371
# min          0.000000
# 25%        271.680000
# 50%        496.540000
# 75%        745.635000
# 90%       1024.842000
# max       2628.420000
# Name: avg_revenue, dtype: float64

# %% [markdown]
# Пользователи с одним заказом по медиане имеют более низкую выручку чем пользователи у которых 2+ заказа
#
# Посмотрим по гистограмме распределения выручки для визуального анализа.

# %%
plt.figure(figsize=(12, 8))

plt.hist(single_order_users['avg_revenue'], bins=30, alpha=0.7, density=True, 
         color='red', label='Пользователи с одним заказом')

plt.hist(returned_users['avg_revenue'], bins=30, alpha=0.7, density=True,
         color='blue', label='Пользователи с 2+ заказами')

plt.title('Распределение средней выручки с заказов пользователей')
plt.xlabel('Средняя выручка с заказа (руб.)')
plt.ylabel('Плотность распределения')
plt.legend()
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# По графику видны различия в распределении выручки между группами, пользователи с одним заказом концентрируются в области более низких значений выручки.
#
# Соответственно, видны различия в распределении средней выручки между пользователями с разным уровнем лояльности, пользователи с повторными заказами имеют статистически более высокую среднюю выручку, и их распределение смещено в сторону более высоких значений по сравнению с пользователями, совершившими только один заказ. Это говорит о том, что размер выручки может быть индикатором потенциальной лояльности пользователя, тоесть если один раз попробовал сервис, то растет на каждом интервале количество повторных пользователей

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Логика общего вывода правильная: пользователи, которые совершают только одну покупку, действительно чаще выбирают самые дешевые билеты, тогда как лояльная аудитория готова платить больше. Это ценный инсайт для бизнеса.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Обрати внимание на строку mean (среднее арифметическое) в твоей таблице статистики. У обеих групп оно практически одинаковое - около 545 рублей. Однако в выводе ты утверждаешь, что пользователи с повторными заказами имеют "статистически более высокую среднюю выручку". Это противоречит цифрам. Разница кроется именно в медиане (строка 50%), которая у вернувшихся пользователей действительно значительно выше. В таких случаях, когда есть выбросы (очень дорогие билеты), лучше ориентироваться на медиану, а не на среднее.
#
# Также стоит добавить конкретики в ответ на вопрос о диапазонах. Ты правильно указал общие тенденции ("более низкие значения"), но для полноты ответа лучше назвать конкретные цифры с графика. Например, отметить, что новички концентрируются в диапазоне до 300 рублей, а пик распределения лояльных пользователей смещен в диапазон 400–800 рублей.

# %% [markdown]
# # Задача 4.2.2: Сравнение распределения по средней выручке между группами пользователей

# %% [markdown]
# Поделим пользователей на две группы по уровню лояльности и посмотрим статистику по выручке для обеих групп

# %%
users_2_4_orders = profiles[(profiles['total_orders'] >= 2) & (profiles['total_orders'] <= 4)]
users_5plus_orders = profiles[profiles['total_orders'] >= 5]

print(f"Пользователей с 2-4 заказами: {len(users_2_4_orders):,}")
print(f"Пользователей с 5+ заказами: {len(users_5plus_orders):,}")

print("\nПользователи с 2-4 заказами:")
print(users_2_4_orders['avg_revenue'].describe(percentiles=[0.25, 0.5, 0.75, 0.9]))
print("\nПользователи с 5+ заказами:")
print(users_5plus_orders['avg_revenue'].describe(percentiles=[0.25, 0.5, 0.75, 0.9]))
# Out:
# Пользователей с 2-4 заказами: 7,145
# Пользователей с 5+ заказами: 6,114
#
# Пользователи с 2-4 заказами:
# count    7145.000000
# mean      552.257387
# std       420.128414
# min         0.000000
# 25%       219.500000
# 50%       472.470000
# 75%       798.830000
# 90%      1115.838000
# max      2628.420000
# Name: avg_revenue, dtype: float64
#
# Пользователи с 5+ заказами:
# count    6114.000000
# mean      536.634203
# std       298.808493
# min         0.000000
# 25%       331.752500
# 50%       513.310000
# 75%       701.095000
# 90%       921.902000
# max      2299.870000
# Name: avg_revenue, dtype: float64

# %% [markdown]
# Получается что пользователи с 5+ заказами имеют более низкую медианную выручку по сравнению с пользователями с 2-4 заказами. Строим гистограмму

# %%
plt.figure(figsize=(12, 8))

plt.hist(users_2_4_orders['avg_revenue'], bins=30, alpha=0.7, density=True, 
         color='orange', label='Пользователи с 2–4 заказами')

plt.hist(users_5plus_orders['avg_revenue'], bins=30, alpha=0.7, density=True,
         color='green', label='Пользователи с 5+ заказами')

plt.title('Распределение средней выручки с заказов вернувшихся пользователей')
plt.xlabel('Средняя выручка с заказа (руб.)')
plt.ylabel('Плотность распределения')
plt.legend()
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# Самые лояльные пользователи (5+ заказов) не только демонстрируют более предсказуемое поведение (меньшее стандартное отклонение), но и в среднем платят больше за заказ, что делает их особенно ценными для бизнеса.
#
# Пользователи с 5+ заказами имеют более высокую медианную выручку (513.31 руб.) по сравнению с пользователями 2-4 заказов (472.47 руб.). Разница составляет 40.84 руб.
#
# С точки зрения разброса значений, стандартное отклонение у группы с 2-4 заказами значительно выше (420.13 руб. против 298.82 руб.), что подтверждает визуальное наблюдение о более широком разбросе значений в этой группе.
#
# По форме распределения, получается что пользователи с 5+ заказами демонстрируют более концентрированное распределение с выраженным пиком в районе 500-600 рублей, а пользователи с 2-4 заказами имеют более широкое распределение со смещением в зону низких чеков (до 300 рублей), где плотность распределения значительно выше.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Ты правильно интерпретировал форму графиков. Действительно, распределение выручки у самых лояльных пользователей (5+ заказов) гораздо более сфокусированное, с явным пиком в районе 500 рублей. Это верное наблюдение: "супер-лояльные" пользователи ведут себя более предсказуемо и однородно. Технически разделение на группы и визуализация выполнены корректно.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Стоит подкрепить визуальный анализ цифрами из таблицы, а именно стандартным отклонением (std). У группы 5+ оно заметно ниже (298 против 420), что математически доказывает твой вывод о более «концентрированном» распределении.
#
# Также описание группы 2-4 заказа как имеющей «более равномерное распределение по всем диапазонам» не совсем точно. На графике видно, что эта группа сильно смещена влево - в зону низких чеков (до 300 рублей), где их столбики значительно выше зеленых.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Ты написал, что пользователи с 5+ заказами имеют более низкую медианную выручку. Однако данные в таблице говорят об обратном: медиана группы 5+ составляет 513 рублей, а группы 2-4 - 472 рубля. То есть самые лояльные пользователи по медиане платят больше, а не меньше. Обязательно исправь это утверждение, так как оно искажает портрет клиента.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Все поправил  </div>

# %% [markdown]
# # Задача 4.2.3: Анализ влияния среднего количества билетов на вероятность повторной покупки

# %% [markdown]
# Посмотрим общее распределение пользователей по среднему количеству билетов

# %%
print(profiles['avg_tickets'].describe(percentiles=[0.25, 0.5, 0.75, 0.9, 0.95]))
# Out:
# count    21622.000000
# mean         2.744260
# std          0.917482
# min          1.000000
# 25%          2.000000
# 50%          2.750000
# 75%          3.100000
# 90%          4.000000
# 95%          4.000000
# max         11.000000
# Name: avg_tickets, dtype: float64

# %% [markdown]
# Среднее количество билетов в заказе составляет 2,74, медиана - 2,75, 75% пользователей покупают до 3-х билетов в среднем за заказ.
#
# Надо сделать сегменты пользователей по количеству билетов и посмотреть распределение

# %%
profiles_copy = profiles.copy()

bins = [1, 2, 3, 5, float('inf')]
labels = ['1-2 билета', '2-3 билета', '3-5 билетов', '5+ билетов']

profiles_copy['tickets_group'] = pd.cut(profiles_copy['avg_tickets'], 
                                       bins=bins, 
                                       labels=labels,
                                       right=False)

print("\nРАСПРЕДЕЛЕНИЕ ПОЛЬЗОВАТЕЛЕЙ ПО СЕГМЕНТАМ БИЛЕТОВ:")
segment_distribution = profiles_copy['tickets_group'].value_counts().sort_index()
total_users = len(profiles_copy)

for segment, count in segment_distribution.items():
    percentage = (count / total_users) * 100
    print(f"   {segment:<12} {count:>6,} пользователей ({percentage:5.1f}%)")
# Out:
# РАСПРЕДЕЛЕНИЕ ПОЛЬЗОВАТЕЛЕЙ ПО СЕГМЕНТАМ БИЛЕТОВ:
#    1-2 билета    2,410 пользователей ( 11.1%)
#    2-3 билета    9,485 пользователей ( 43.9%)
#    3-5 билетов   9,066 пользователей ( 41.9%)
#    5+ билетов      661 пользователей (  3.1%)

# %% [markdown]
# Распределены пользователи неравномерно, наибольшая концентрация наблюдается в сегменте по 2-3 билета
#
# Далее анализируем долю возврата по каждому сегменту.

# %%
grouped_analysis = profiles_copy.groupby('tickets_group').agg(
    user_count=('avg_tickets', 'count'),
    is_two_count=('is_two', 'sum'),
    is_two_mean=('is_two', lambda x: round(x.mean() * 100, 2)),
    is_five_count=('is_five', 'sum'),
    is_five_mean=('is_five', lambda x: round(x.mean() * 100, 2))
).reset_index()

print("\nАНАЛИЗ ДОЛИ ВОЗВРАТА ПО СЕГМЕНТАМ БИЛЕТОВ:")
print("Сегмент       | Пользователей | Доля 2+ заказов | Доля 5+ заказов")


for _, row in grouped_analysis.iterrows():
    print(f"{row['tickets_group']:<12} | {row['user_count']:>12,} | {row['is_two_mean']:>15}% | {row['is_five_mean']:>14}%")

avg_is_two = profiles_copy['is_two'].mean() * 100
avg_is_five = profiles_copy['is_five'].mean() * 100
print(f"\nСреднее по выборке: | {'':>12} | {avg_is_two:>15.1f}% | {avg_is_five:>14.1f}%")
# Out:
# АНАЛИЗ ДОЛИ ВОЗВРАТА ПО СЕГМЕНТАМ БИЛЕТОВ:
# Сегмент       | Пользователей | Доля 2+ заказов | Доля 5+ заказов
# 1-2 билета   |        2,410 |           51.24% |          14.27%
# 2-3 билета   |        9,485 |           73.56% |          41.18%
# 3-5 билетов  |        9,066 |            54.3% |          20.42%
# 5+ билетов   |          661 |           18.76% |           1.97%
#
# Среднее по выборке: |              |            61.3% |           28.3%

# %% [markdown]
# Сегмент 2-3 билета также показывает наивысшую долю возврата, что значительно выше среднего по выборке.
#
# Стриом графики и смотрим распределение пользователей и долю возврата по сегментам.

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

segment_distribution.plot(kind='bar', ax=ax1, color='lightblue')
ax1.set_title('Распределение пользователей по сегментам билетов')
ax1.set_xlabel('Сегмент по количеству билетов')
ax1.set_ylabel('Количество пользователей')
ax1.tick_params(axis='x', rotation=45)

for i, count in enumerate(segment_distribution.values):
    ax1.text(i, count, f'{count/total_users*100:.1f}%', 
             ha='center', va='bottom')

grouped_analysis.plot(x='tickets_group', y='is_two_mean', kind='bar', ax=ax2, color='lightgreen')
ax2.axhline(y=avg_is_two, color='red', linestyle='--', label=f'Среднее ({avg_is_two:.1f}%)')
ax2.set_title('Доля пользователей с 2+ заказами по сегментам')
ax2.set_xlabel('Сегмент по количеству билетов')
ax2.set_ylabel('Доля пользователей с 2+ заказами (%)')
ax2.tick_params(axis='x', rotation=45)
ax2.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Визуализация подтверждает неравномерное распределение пользователей и выявляет сегмент "2-3 билета" как наиболее успешный с точки зрения возврата.

# %% [markdown]
# Анализ выявил сильную зависимость между средним количеством билетов в заказе и вероятностью возврата пользователя. Наиболее лояльными оказываются пользователи, покупающие 2-3 билета за раз (74% возврата), в то время как пользователи с очень мелкими (1-2 билета) и очень крупными (5+ билетов) заказами демонстрируют значительно более низкую лояльность. Распределение пользователей по сегментам сильно неравномерное с концентрацией в сегменте 2-3 билета.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Ты верно выполнил сегментацию пользователей согласно заданию и рассчитал метрики для каждой группы. Графики получились наглядными, особенно полезной оказалась красная линия среднего уровня возвращаемости, которая сразу подсвечивает успешные и отстающие сегменты.
#
# Главный вывод сделан правильно: существует нелинейная зависимость между размером заказа и лояльностью. Ты обоснованно выделил группу пользователей, покупающих 2-3 билета, как "золотую середину" с максимальным удержанием.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> В анализе распределения пользователей ты указал на концентрацию в сегменте 2-3 билета. Однако стоит заметить, что соседний сегмент (3-5 билетов) отстает от лидера всего на 2% (41.9% против 43.9%). Будет точнее сказать, что основная масса аудитории сосредоточена в широком диапазоне от 2 до 5 билетов, так как эти две группы вместе составляют подавляющее большинство.
#
# Также обрати внимание на форматирование чисел в итоговой таблице с долями возврата. Значения имеют разное количество знаков после запятой (где-то один, где-то два), лучше приводить их к единообразию для аккуратности отчета.

# %% [markdown]
# # Задача 4.3 Исследование временных характеристик первого заказа и их влияния на повторные покупки
#
# # Задача 4.3.1: Анализ влияния дня недели первой покупки на поведение пользователей

# %% [markdown]
# Сначала создаем копию профилей для анализа, извлекаем день недели из даты первого заказа, определяем правильный порядок дней недели, группируем по дням недели

# %%
profiles_copy = profiles.copy()

profiles_copy['first_order_weekday'] = profiles_copy['first_order'].dt.day_name()

weekday_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
weekday_russian = ['Понедельник', 'Вторник', 'Среда', 'Четверг', 'Пятница', 'Суббота', 'Воскресенье']

weekday_analysis = profiles_copy.groupby('first_order_weekday').agg(
    user_count=('first_order', 'count'),
    is_two_mean=('is_two', lambda x: round(x.mean() * 100, 2))
).reindex(weekday_order)

print("РАСПРЕДЕЛЕНИЕ ПО ДНЯМ НЕДЕЛИ:")
for i, (day_eng, day_rus) in enumerate(zip(weekday_order, weekday_russian)):
    count = weekday_analysis.loc[day_eng, 'user_count']
    retention = weekday_analysis.loc[day_eng, 'is_two_mean']
    print(f"   {day_rus:<12} {count:>6,} пользователей ({retention:>5.1f}% возврата)")
# Out:
# РАСПРЕДЕЛЕНИЕ ПО ДНЯМ НЕДЕЛИ:
#    Понедельник   2,918 пользователей ( 63.0% возврата)
#    Вторник       3,175 пользователей ( 61.9% возврата)
#    Среда         3,061 пользователей ( 62.3% возврата)
#    Четверг       3,112 пользователей ( 59.5% возврата)
#    Пятница       3,256 пользователей ( 59.8% возврата)
#    Суббота       3,323 пользователей ( 62.8% возврата)
#    Воскресенье   2,777 пользователей ( 60.1% возврата)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

weekday_analysis['user_count'].plot(kind='bar', ax=ax1, color='skyblue')
ax1.set_title('Распределение пользователей по дню недели первого заказа')
ax1.set_xlabel('День недели')
ax1.set_ylabel('Количество пользователей')
ax1.set_xticklabels(weekday_russian, rotation=45)

weekday_analysis['is_two_mean'].plot(kind='bar', ax=ax2, color='lightgreen')
ax2.axhline(y=profiles_copy['is_two'].mean()*100, color='red', linestyle='--', 
            label=f'Среднее ({profiles_copy["is_two"].mean()*100:.1f}%)')
ax2.set_title('Доля вернувшихся пользователей по дню недели первого заказа')
ax2.set_xlabel('День недели')
ax2.set_ylabel('Доля вернувшихся пользователей (%)')
ax2.set_xticklabels(weekday_russian, rotation=45)
ax2.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Наибольшее количество первых заказов приходится на пятницу и субботу, наименьшее - на воскресенье и понедельник. Доля возврата варьируется от 59% до 63%.
#
# График распределения пользователей и долю возврата по дням недели показывает неравномерное распределение пользователей по дням недели и различия в доле возврата.
#
# Поэтому день недели первой покупки не оказывает статистически значимое влияние на вероятность возврата пользователя, и практическая значимость этого влияния ограничена из-за небольшого диапазона различий (менее 4% между лучшим и худшим днем). Наибольшую лояльность демонстрируют пользователи, совершившие первую покупку в понедельник, наименьшую - в четверг.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Ты правильно рассчитал метрики и верно определил дни-лидеры: пятницу и субботу по количеству заказов, а понедельник - по доле возвратов. Твои наблюдения полностью совпадают с цифрами в таблице. Также ценно, что ты оценил масштаб различий, заметив, что разброс показателей возвращаемости между днями достаточно узкий (около 4%).

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Будь осторожнее с фразой «статистически значимое влияние». В аналитике это строгий термин, который подразумевает проведение специальных математических тестов (например, t-теста или хи-квадрат). Если ты такие тесты не проводил, безопаснее использовать формулировки вроде «существенное» или «заметное» влияние.
#
# Также стоит аккуратнее подходить к выводу об отсутствии влияния. Разница в удержании в 3.5% (между 59.5% и 63%) в масштабах бизнеса может приносить ощутимую прибыль или убыток. Полностью списывать этот фактор со счетов не стоит - возможно, пользователи понедельника качественнее аудитории четверга.

# %% [markdown]
# # Задача 4.3.2: Анализ влияния среднего интервала между заказами на удержание клиентов

# %% [markdown]
# Разделим пользователей на две группы по уровню лояльности и определим средний интервал для обеих групп

# %%
users_2_4_orders = profiles[(profiles['total_orders'] >= 2) & (profiles['total_orders'] <= 4)]
users_5plus_orders = profiles[profiles['total_orders'] >= 5]

print("АНАЛИЗ СРЕДНЕГО ИНТЕРВАЛА МЕЖДУ ЗАКАЗАМИ:")

avg_interval_2_4 = users_2_4_orders['avg_days_between_orders'].mean()
avg_interval_5plus = users_5plus_orders['avg_days_between_orders'].mean()

print(f"Пользователи с 2-4 заказами: {avg_interval_2_4:.1f} дней")
print(f"Пользователи с 5+ заказами:  {avg_interval_5plus:.1f} дней")
print(f"Разница: {avg_interval_2_4 - avg_interval_5plus:.1f} дней ({avg_interval_2_4/avg_interval_5plus:.1f}x)")
# Out:
# АНАЛИЗ СРЕДНЕГО ИНТЕРВАЛА МЕЖДУ ЗАКАЗАМИ:
# Пользователи с 2-4 заказами: 21.3 дней
# Пользователи с 5+ заказами:  9.9 дней
# Разница: 11.4 дней (2.2x)

# %%
groups_data = pd.Series({
    '2-4 заказа': avg_interval_2_4,
    '5+ заказов': avg_interval_5plus
})

plt.figure(figsize=(10, 6))
groups_data.plot(kind='bar', color=['lightblue', 'lightgreen'])
plt.title('Зависимость среднего времени между заказами от количества заказов')
plt.xlabel('Количество заказов пользователей')
plt.ylabel('Среднее время между заказами (дни)')
plt.xticks(rotation=45)
plt.grid(axis='y', alpha=0.3)


for i, value in enumerate(groups_data.values):
    plt.text(i, value + 0.5, f'{value:.1f} дней', ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %% [markdown]
# На графике виднодвукратную разницу в частоте заказов между группами пользователей.

# %% [markdown]
# # Вывод по задаче 4.3.2:
# Средний интервал между заказами значимо влияет на удержание клиентов, т.к. пользователи с 5+ заказами совершают покупки в 2 раза чаще каждые 9 дней, чем пользователи с 2-4 заказами каждые 21 день. Эта зависимость демонстрирует, что частота покупок является важным индикатором лояльности пользователей - чем чаще пользователь совершает заказы, тем выше вероятность, что он станет постоянным клиентом платформы.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Ты верно выполнил расчеты среднего времени между заказами для обеих групп. Цифры на графике и в текстовом описании (21.3 и 9.9) совпадают, а разница в 2.2 раза подсчитана корректно.
#
# Главный вывод сформулирован правильно: ты определил четкую взаимосвязь между частотой покупок и лояльностью. Идея о том, что короткий интервал между заказами является индикатором качественного клиента, полезна для бизнеса.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Обрати внимание на округление в текстовом выводе. Ты пишешь, что пользователи с 5+ заказами совершают покупки «каждые 9 дней». Однако значение 9.9 математически ближе к 10 дням. В аналитике лучше округлять по правилам арифметики или указывать точное число, чтобы не завышать частоту покупок.
#
# Также стоит заметить нюанс в логике ответа на второй пункт задания. Задание просило изучить, как интервал влияет на вероятность повторного заказа. Ты же пошел от обратного: взял уже сформированные группы лояльности и посмотрел их интервал. Это не ошибка, так как корреляция очевидна, но более глубокий анализ мог бы показать, например, что если новый пользователь делает второй заказ в течение 10 дней, то вероятность его перехода в сегмент 5+ резко возрастает.

# %% [markdown]
# # Задача 4.4: Корреляционный анализ количества покупок и признаков пользователя

# %% [markdown]
# Делаем подготовку данных для корреляционного анализа, определяем интервальные переменные, определяем интервальные переменные для расчета коэффициента корреляции

# %%
print(profiles.columns.tolist())
# Out:
# ['first_order', 'last_order', 'first_device', 'first_region', 'first_service', 'first_event_type', 'total_orders', 'avg_revenue', 'avg_tickets', 'avg_days_between_orders', 'is_two', 'is_five']

# %%
correlation_data = profiles[['total_orders', 'avg_revenue', 'avg_tickets', 'avg_days_between_orders',
                           'first_device', 'first_event_type', 'first_service', 'first_region']].copy()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Подскажи, почему для анализа корреляции выбраны только эти признаки? В задании сказано `между признаками профиля и числом заказов`, то есть перечень признаков никак явно не усекается.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Хорошо, я невнимательно прочитал
#
# Сделаем больше признаков
#     Поправил
#     </div>

# %%
interval_cols = ['total_orders', 'avg_revenue', 'avg_tickets', 'avg_days_between_orders']
corr_matrix = correlation_data.phik_matrix(interval_cols=interval_cols)
total_orders_corr = corr_matrix['total_orders'].sort_values(ascending=False)

print("\nКорреляция с total_orders:")
for feature, corr_value in total_orders_corr.items():
    if feature != 'total_orders':
        print(f"  {feature:<25} {corr_value:.3f}")
# Out:
# Корреляция с total_orders:
#   avg_days_between_orders   0.284
#   avg_tickets               0.225
#   avg_revenue               0.219
#   first_region              0.115
#   first_event_type          0.029
#   first_service             0.029
#   first_device              0.026

# %% [markdown]
# Наибольшая корреляция наблюдается с avg_days_between_orders, что намекает на связь частоты заказов с лояльностью
#
# Создадим тепловую карту коррелляций для всех пользователей

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.3f', 
            linewidths=0.5, center=0)
plt.title('Матрица корреляции Phi_k для всех пользователей')
plt.tight_layout()
plt.show()

# %% [markdown]
# По тепловой карте наглядно видим силу корреляций между разными признаками.
#
# Далее анализ корреляции для разных уровней лояльности, используя бинарные признаки

# %%
users_1_order = profiles[profiles['total_orders'] == 1]
users_2_4_orders = profiles[(profiles['total_orders'] >= 2) & (profiles['total_orders'] <= 4)]
users_5plus_orders = profiles[profiles['total_orders'] >= 5]

segments_with_variation = [
    ('2-4 заказа', users_2_4_orders),
    ('5+ заказов', users_5plus_orders)
]

features_for_corr = ['total_orders', 'avg_revenue', 'avg_tickets', 'avg_days_between_orders']

for segment_name, segment_data in segments_with_variation:
    if len(segment_data) > 0:
        segment_corr = segment_data[features_for_corr].phik_matrix(interval_cols=features_for_corr)
        print(f"\n{segment_name} (n={len(segment_data):,}):")
        
        total_orders_corr_segment = segment_corr['total_orders'].sort_values(ascending=False)
        for feature, corr_value in total_orders_corr_segment.items():
            if feature != 'total_orders':
                strength = "сильная" if corr_value >= 0.3 else "умеренная" if corr_value >= 0.1 else "слабая"
                print(f"  {feature:<25} {corr_value:.3f} ({strength})")
# Out:
# 2-4 заказа (n=7,145):
#   avg_days_between_orders   0.386 (сильная)
#   avg_tickets               0.369 (сильная)
#   avg_revenue               0.109 (умеренная)
#
# 5+ заказов (n=6,114):
#   avg_days_between_orders   0.696 (сильная)
#   avg_revenue               0.239 (умеренная)
#   avg_tickets               0.161 (умеренная)

# %% [markdown]
# В сегменте 1 заказ корреляции маленькие, в других сегментах наблюдаются различные паттерны.
#
# Далее анализ категориальных признаков первого заказа (используем ТОЛЬКО поведенческие признаки (без total_orders))

# %%
behavioral_features = ['avg_revenue', 'avg_tickets', 'avg_days_between_orders']

for segment_name, segment_data in [('1 заказ', users_1_order), 
                                  ('2-4 заказа', users_2_4_orders),
                                  ('5+ заказов', users_5plus_orders)]:
    if len(segment_data) > 0:
        segment_features = segment_data[behavioral_features].copy()
        segment_corr_matrix = segment_features.phik_matrix(interval_cols=behavioral_features)
        
        print(f"\n{segment_name} - взаимосвязи между поведенческими признаками:")
        for i, feature1 in enumerate(behavioral_features):
            for j, feature2 in enumerate(behavioral_features):
                if i < j:  
                    corr_value = segment_corr_matrix.loc[feature1, feature2]
                    strength = "сильная" if abs(corr_value) >= 0.3 else "умеренная" if abs(corr_value) >= 0.1 else "слабая"
                    print(f"  {feature1} ↔ {feature2}: {corr_value:.3f} ({strength})")
# Out:
# 1 заказ - взаимосвязи между поведенческими признаками:
#   avg_revenue ↔ avg_tickets: 0.460 (сильная)
#   avg_revenue ↔ avg_days_between_orders: 0.000 (слабая)
#   avg_tickets ↔ avg_days_between_orders: 0.000 (слабая)
#
# 2-4 заказа - взаимосвязи между поведенческими признаками:
#   avg_revenue ↔ avg_tickets: 0.316 (сильная)
#   avg_revenue ↔ avg_days_between_orders: 0.175 (умеренная)
#   avg_tickets ↔ avg_days_between_orders: 0.107 (умеренная)
#
# 5+ заказов - взаимосвязи между поведенческими признаками:
#   avg_revenue ↔ avg_tickets: 0.350 (сильная)
#   avg_revenue ↔ avg_days_between_orders: 0.177 (умеренная)
#   avg_tickets ↔ avg_days_between_orders: 0.089 (слабая)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Не забывай про настройку `interval_cols`.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Тут исправил тоже</div>

# %%
categorical_features = ['first_device', 'first_event_type', 'first_service', 'first_region']
categorical_correlations = {}

for feature in categorical_features:
    temp_df = profiles[['total_orders', feature]].copy()
    corr_matrix_temp = temp_df.phik_matrix(interval_cols=['total_orders'])
    corr_value = corr_matrix_temp.loc['total_orders', feature]
    categorical_correlations[feature] = corr_value

cat_corr_series = pd.Series(categorical_correlations).sort_values(ascending=False)
print("\nКорреляция категориальных признаков с total_orders:")
for feature, corr_value in cat_corr_series.items():
    strength = "сильная" if corr_value >= 0.3 else "умеренная" if corr_value >= 0.1 else "слабая"
    print(f"  {feature:<20} {corr_value:.3f} ({strength})")
# Out:
# Корреляция категориальных признаков с total_orders:
#   first_region         0.115 (умеренная)
#   first_event_type     0.029 (слабая)
#   first_service        0.029 (слабая)
#   first_device         0.026 (слабая)

# %% [markdown]
# Тут все признаки показывают слабую корреляцию с количеством заказов.
#
# Поэтому наиболее сильная связь с количеством заказов наблюдается только у среднего интервала между заказами где phi_k = 0.494. Категориальные признаки первого заказа (тип мероприятия, устройство, регион, оператор) показывают слабую корреляцию с общим количеством заказов пользователя.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>Ты верно провел анализ числовых признаков. Тепловая карта построена корректно, а коэффициенты для среднего интервала, количества билетов и выручки считаны правильно.
#
# Вывод о том, что частота покупок (интервал между заказами) имеет самую сильную связь с общим количеством заказов среди числовых переменных, логичен и подтверждается полученным значением 0.49.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> В части с сегментацией пользователей есть неточность в интерпретации задачи. Цель разделения на сегменты - проверить корреляцию признаков с полем total_orders внутри этих групп. Однако на скриншотах для сегментов (1 заказ, 2-4 заказа, 5+) в матрицах отсутствует сама строка или столбец total_orders. Ты проанализировал связь косвенных признаков (выручки, билетов и дней) друг с другом, но не их связь с целевой переменной (количеством заказов) внутри сегмента.
#
# В блоке анализа категориальных признаков есть грубое противоречие между данными на экране и твоим выводом. В таблице напротив всех категорий (тип мероприятия, устройство, регион, сервис) стоит коэффициент корреляции 1.000. Это означает идеальную, стопроцентную зависимость. Однако в текстовом выводе ты пишешь, что признаки показывают "слабую корреляцию".
#
# Значение 1.000 для всех признаков выглядит как техническая ошибка в коде (возможно, некорректно переданы данные в функцию или неверно обработаны индексы). Тебе нужно найти причину получения единиц, пересчитать корреляцию и написать вывод, соответствующий новым, реальным цифрам. Сейчас вывод полностью противоречит таблице результатов.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# В сегментации теперь анализирую связь признаков с вариацией total_orders внутри каждой группы, а не взаимосвязи между признаками, и исправил техническую ошибку с категориальными признаками - пересчитал корреляцию, теперь значения реальные (0.02-0.12), а не 1.000</div>

# %% [markdown]
# # Шаг 5: Общие выводы и рекомендации
# # Информация о данных и подготовка
#
# 1. Подготовка данных и ключевые метрики
#
# Проанализировано 21622 пользователей после очистки данных
#
# Удалено 1.1% записей (отрицательная выручка, выбросы)
#
# 61% пользователей совершили 2+ заказа, 28% - 5+ заказов
#
# Средняя выручка: 545 руб, среднее количество билетов: 2.74
#
# 2. Ключевые инсайты по лояльности
#
# Точки входа:
#
# Концерты - 44% первых заказов, 61% возврата
#
# Мобильные устройства - 82% первых заказов
#
# Каменевский регион - 32% пользователей, 62% возврата
#
# "Билеты без проблем" - 23% первых заказов
#
# 3. Факторы удержания:
#
# Оптимальная выручка: 500-600 руб. (пик лояльности)
#
# Количество билетов: 2-3 билета (73% возврата)
#
# Интервал между заказами: 9.9 дней у лояльных vs 21.3 дней у умеренных
#
# День недели: понедельник (63% возврата)
#
# 4. Корреляционный анализ
#
# Сильная связь: интервал между заказами (0.494)
#
# Умеренная связь: количество билетов (0.290), выручка (0.251)
#
# Слабая связь: категориальные признаки первого заказа
#
#
# # РЕКОМЕНДАЦИИ
#
# 1. Приоритетные сегменты:
#
# Пользователи с первым заказом на концерты через мобильные устройства
#
# Клиенты с средним чеком 500-600 руб. и 2-3 билетами в заказе
#
# Пользователи с интервалами между заказами 7-14 дней
#
# 2. Стратегии удержания:
#
# Разработать программу лояльности для "золотого" сегмента (2-3 билета, 500-600 руб.)
#
# Усилить онбординг для пользователей выставок и спортивных мероприятий
#
# Внедрить триггерные уведомления за 7-10 дней после предыдущего заказа
#
# 3. Продуктовые улучшения:
#
# Оптимизировать мобильный опыт (82.8% первых заказов)
#
# Создать персонализированные рекомендации для пользователей концертов
#
# Разработать систему напоминаний для поддержания оптимальной частоты заказов
#
# ЗАКЛЮЧЕНИЕ
# Анализ выявил четкие закономерности в поведении лояльных пользователей. Ключевые факторы успеха - оптимальное сочетание характеристик первого заказа, финансовых параметров и временных интервалов. Реализация рекомендаций позволит системно повысить удержание клиентов и увеличить долю возвращающихся пользователей.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Ты подготовил отличный итоговый отчет. Структура полностью соответствует требованиям задания: есть и описание данных, и ключевые метрики, и, что самое важное - прикладные рекомендации.
#
# Особенно хочу отметить связь между аналитикой и бизнес-решениями. Твое предложение внедрить триггерные уведомления на 7–10 день основано на конкретной цифре среднего интервала (9.9 дней) у лояльных пользователей. Это пример качественного data-driven подхода, когда цифры превращаются в конкретное действие для маркетинга.
#
# Также хорошо, что ты выделил «золотой сегмент» (2–3 билета, чек 500–600 руб.) и предложил сфокусировать программу лояльности именно на нем.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> В блоке с описанием подготовки данных стоит добавить пару слов о валюте. Задание просило упомянуть перевод тенге в рубли - ты указываешь суммы в рублях, но сам факт конвертации в тексте явно не прописан. Это мелочь, но она показывает прозрачность твоей работы с исходным датасетом.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Публикация в Git
#
# Я прошу прощения, тут уже в ночи делал, не совсем понял что обязательно надо публиковать в Git, и подумал что достаточно просто направить на проверку тетрадку. Сейчас увидел твой комментарий, еще раз перечитал задание, исправляю    </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Рад, что разобрались:)

# %% [markdown]
# # 6. Финализация проекта и публикация в Git

# %% [markdown]
# ССылка на проект в GitHub
#
# **Ссылка на репозиторий:** https://github.com/danfreeman23/Module_2_Project

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Файлы проекта добавлены в репозиторий.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> В версии, которую ты заливаешь на `GitHub`, не стоит оставлять параметры подключения в явном виде - это может привести к несанкционированному доступу к данным, что чревато их потереей или изменением. Лучшее решение - локально создать `.env` файл, из которого с помощью `os` эти параметры подключения передаются в код. А файл `.gitignore` поможет не отслеживать этот файл для репозитория.
#
# Файл `.env` может выглядеть так:
#
# ```python
# DB_NAME="..."
# DB_HOST="..."
# DB_PORT="..."
# DB_USER="..."
# DB_PASSWORD="..."
# ```
#
# В самом проекте мы можем обращаться к сохраненным параметрам с помощью библиотеки `dotenv`, чтобы загрузить переменные окружения, и `os`, чтобы обратиться к ним:
#
# ```python
# import os
# import dotenv
#
# load_dotenv() # автоматически ищет .env в текущей директории
#
# connection_string = 'postgresql://{}:{}@{}:{}/{}'.format(
#     os.getenv('DB_USER'),
#     os.getenv('DB_PASSWORD'),
#     os.getenv('DB_HOST'),
#     os.getenv('DB_PORT'),
#     os.getenv('DB_NAME'),
# )
# ```

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Пароль из кода убрал. Хоть и не сразу сообразил как, в начале кода покопался, в env скорректировал  </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Очень прошу Вас принять работу до наступления жесткого дедлайна, для продолжения обучения. Или же прошу рассмотреть возможность устранения замечаний если остались, после дедлайна, но при этом с продолжением дальнешей программы обучения  </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Такой формат работы никто из ревьюеров не практикует, к сожалению.

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: общий вывод по проекту.
#
# Даниил, проект получился на довольно хорошем уровне - отличная работа над проектом, молодец!
#
# Мне нравится твой аналитический подход к выполнению проекта, ты соблюдаешь структуру работы, выполняешь её последовательно - это очень хорошо! Шаги проекта выполнены по порядку согласно плану проекта, нет смысловых и структурных ям. Важно, что не забываешь про выводы.
#
# Над проектом ещё стоит поработать - есть рекомендации по дополнению некоторых твоих шагов проекта. Такие рекомендации я отметил жёлтыми комментариями. Будет здорово, если ты учтёшь их - так проект станет структурно и содержательно более совершенным.
#
# Также в работе есть критические замечания. К этим замечаниям я оставил пояснительные комментарии красного цвета, в которых перечислил возможные варианты дальнейших действий. Уверен, ты быстро с этим управишься:)
#
# Если о том, что нужно сделать в рамках комментариев, будут возникать вопросы - оставь их, пожалуйста, в комментариях, и я отвечу на них во время следующего ревью.
#
# Также буду рад ответить на любые твои вопросы по проекту или на какие-либо другие, если они у тебя имеются - оставь их в комментариях, и я постараюсь ответить:)
#
# Жду твой проект на повторном ревью. До встречи:)

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Поскольку только поздно вечером могу заниматься учебой, и уходит уже в ночь, а завтра (сегодня) с 8 утра весь день в совещаниях высокоуровневых с руководством, с заказчиками и т.д., то сфокусировался на корректирвоке только красных комментариев, требущих доработок, а на желтые уже не хватило времени. Прошу ознакомиться и принять работу. Спасибо </div>
